# %%
import urllib.request as req

# 이미지 다운로드
url = "https://images.unsplash.com/photo-1568967729548-e3dbad3d37e0?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=334&q=80"
req.urlretrieve(url, "test.png")

# OpenCV로 읽어들이기
import cv2
img = cv2.imread("test.png")
print(img)
# Out:
# [[[185 185 185]
#   [186 186 186]
#   [187 187 187]
#   ...
#   [176 176 176]
#   [174 174 174]
#   [173 173 173]]
#
#  [[186 186 186]
#   [187 187 187]
#   [188 188 188]
#   ...
#   [178 178 178]
#   [176 176 176]
#   [175 175 175]]
#
#  [[187 187 187]
#   [188 188 188]
#   [189 189 189]
#   ...
#   [180 180 180]
#   [179 179 179]
#   [178 178 178]]
#
#  ...
#
#  [[ 15  15  15]
#   [ 15  15  15]
#   [ 16  16  16]
#   ...
#   [ 19  19  19]
#   [ 19  19  19]
#   [ 19  19  19]]
#
#  [[ 15  15  15]
#   [ 15  15  15]
#   [ 15  15  15]
#   ...
#   [ 18  18  18]
#   [ 18  18  18]
#   [ 19  19  19]]
#
#  [[ 15  15  15]
#   [ 15  15  15]
#   [ 15  15  15]
#   ...
#   [ 18  18  18]
#   [ 18  18  18]
#   [ 18  18  18]]]

# %%
import matplotlib.pyplot as plt
import cv2

# 다운로드한 이미지 출력하기(그래프에 띄우기)
img = cv2.imread("test.png")

# 이미지 사이즈 조절
# im2 = cv2.resize(img, (600, 300))
# cv2.imwrite("out-resize.png", im2)

# 이미지 자르고 조절
# im2 = img[150:450, 150:450]
# im2 = cv2.resize(im2, (400, 400))
# cv2.imwrite("cut-resize.png")

plt.axis("off") # x, y축 없애기
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
