# %% [markdown]
# ## 패키지 설치

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import stemgraphic

# %% [markdown]
# # 3-4

# %% [markdown]
# ### (b)

# %%
# 데이터 가져오기

data = pd.read_table("Q3_4.txt", header=None)

minutesCol = list(data[0]) + (list(data[2]))
copiersCol = list(data[1]) + list(data[3])

result = {
    "minutes" : minutesCol,
    "copiers" : copiersCol
}


df = pd.DataFrame(result)

df = df.sort_values(by='minutes',ascending=True)

df.head()
# Out:
#     minutes  copiers
# 34        3        1
# 8         4        1
# 63        9        5
# 4        12        1
# 78       14        4

# %%
# 그래프 작성

x_values = df["copiers"][:, np.newaxis]
y_values = df["minutes"][:, np.newaxis]


model = LinearRegression()

model.fit(x_values, y_values)
y_pred = model.predict(x_values)

residuals = y_values - y_pred

scatter = plt.scatter(x_values, residuals)

plt.title("Time Plot")
plt.ylabel("Residuals")
plt.xlabel("Number of copiers")
# Out:
# Text(0.5, 0, 'Number of copiers')

# %% [markdown]
# ### (c)

# %%
# stem and leaf 그래프(잔차)

x_values = df["copiers"][:, np.newaxis]
y_values = df["minutes"][:, np.newaxis]

model = LinearRegression()

model.fit(x_values, y_values)

y_pred = model.predict(x_values)

residuals = y_values - y_pred

fig, ax = stemgraphic.stem_graphic(residuals)

# %% [markdown]
# ### (d)

# %%
# 잔차 그래프

# ei vs y^
graph1 = plt.scatter(y_pred, residuals)

plt.title("ei vs y hat")
plt.ylabel("Residuals")
plt.xlabel("y hat")
# Out:
# Text(0.5, 0, 'y hat')

# %%
# ei vs x
graph2 = plt.scatter(x_values, residuals)

plt.title("ei vs xi")
plt.ylabel("Residuals")
plt.xlabel("xi")
# Out:
# Text(0.5, 0, 'xi')
